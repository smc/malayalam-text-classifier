# %%
# !pip install transformers

# %%
! pip install https://github.com/huggingface/transformers/archive/nllb.zip -q
# Out:
#      \ 12.2 MB 6.1 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
#      |████████████████████████████████| 6.6 MB 7.6 MB/s
#      |████████████████████████████████| 596 kB 61.4 MB/s
#      |████████████████████████████████| 101 kB 13.2 MB/s
# ...

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM, pipeline

# %%
model = AutoModelForSeq2SeqLM.from_pretrained("facebook/nllb-200-distilled-600M")
tokenizer = AutoTokenizer.from_pretrained("facebook/nllb-200-distilled-600M")

# %%
translator = pipeline('translation', model=model, tokenizer=tokenizer, src_lang="tam_Taml", tgt_lang='mal_Mlym', max_length = 400)

# %%
translator("காலை எப்படி இருக்கிறீர்கள்")
# Out:
# [{'translation_text': 'രാവിലെ എങ്ങനെ'}]

# %%
translator("திஸ் ஐஸ் எ வெரி குட் மாடல் ")
# Out:
# [{'translation_text': 'ഈ ഐസ് എ വരി ഗുഡ് മോഡൽ.'}]

# %%
translator = pipeline('translation', model=model, tokenizer=tokenizer, src_lang="mal_Mlym", tgt_lang='tam_Taml', max_length = 400)

# %%
translator("തിരുവനന്തപുരം-എറണാകുളം")
# Out:
# [{'translation_text': 'திருவனந்தபுரம்-எரணகுளம்'}]

# %%
translator("നെന്മാറ - നെല്ലിയാമ്പതി")
# Out:
# [{'translation_text': 'அறுவடை'}]
